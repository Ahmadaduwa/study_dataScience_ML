# %% [markdown]
# # Workshop 1&2: Bar Chart

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6]
ydata = [1,2.8,2.1,4,3,3.5]

plt.bar(x, ydata)
plt.show()

# %% [markdown]
# # Workshop 3: Save graph to file

# %%
x = [1,2,3,4,5,6]
y = [1,2.8,2.1,4,3,3.5]
plt.bar(x, ydata)

plt.savefig("matplot01.png")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [1,2.8,2.1,4,3,3.5]
plt.bar(x, ydata)

plt.savefig("matplot01.pdf")

plt.tight_layout()
plt.savefig("matplot02.png", dpi=120)
plt.savefig("matplot03.png", dpi=50, transparent=True)

plt.show()

# %% [markdown]
# # Workshop 4: Line Graph

# %%
plt.plot(x, ydata)
plt.show()

# %% [markdown]
# # Workshop 5: Line Graph with many variable

# %%
x = [1,2,3,4,5,6]
y = [1,2.8,2.1,4,3,3.5]
z = [2.2,1.6,2.3,2.0,2.3,2.1]

plt.plot(x, y)
plt.plot(x, z)
plt.show()

# %% [markdown]
# # Workshop 6: Circle Graph

# %%
month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
ydata = [1,3,2.5,4,3,3.5]
expl = (0, 0.15, 0, 0, 0, 0) #แตกชิ้นของข้อมูลที่ 2 Feb 0.15 คือระยะที่แตกออกมา
plt.pie(ydata, explode=expl, labels=month, autopct="%.1f%%", shadow=True, startangle=90)
plt.show()

# %% [markdown]
# # Workshop 7: Scatter

# %%
x = [1,2,3,4,5,6]
ydata = [1,2.8,2.1,4,3,3.5]

plt.scatter(x, ydata)
plt.show()

# %%
x2 = [1.1,2,3,3.9,5.1,6]
ydata2 = [2.2,1.6,2.3,2.0,2.3,2.1]

plt.scatter(x, ydata)
plt.scatter(x2, ydata2)
plt.show()

# %% [markdown]
# # Workshop 8: Histogram

# %%
age = [18,17,20,18,18,17,19,21,18,17,18,17,18,18,19,19,18,17]

plt.hist(age)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame(age, columns=["Age"])
df.head()
df.Age.value_counts()
# Out:
# Age
# 18    8
# 17    5
# 19    3
# 20    1
# 21    1
# Name: count, dtype: int64

# %% [markdown]
# ## ข้อมูลชนิดต่อเนื่อง

# %%
import numpy as np
wt = np.random.normal(10, 2.5, 5000)

plt.hist(wt) #default=10
plt.show()

plt.hist(wt, bins=50)
plt.show()

# %%
wt[:10]
# Out:
# array([12.12755292,  9.70532672,  6.14661651, 13.18695757, 10.65718742,
#        13.73406178,  9.26528165, 13.42273324,  9.75976494, 12.27044893])

# %% [markdown]
# # Workshop 9: Boxplot

# %%
age = [18,17,20,18,18,17,19,21,18,17,18,17,18,18,19,19,18,17,22]
plt.grid() #มีเส้น
plt.boxplot(age)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Workshop 10: Graph with set details

# %%
xs = [1,2,3,4,5,6]
ydata = [1,2.8,2.1,4,3,3.5]
ydata2 = [2.2,1.6,2.3,2,2.3,2.1]

plt.rcParams.update({"font.size":15, "font.family":"tahoma"})
plt.figure(figsize=(6,4)) #กว้าง สูง

plt.grid(linestyle="--", axis='y')
plt.bar(x, ydata, color='c', width=0.5, label='ในประเทศไทย')
plt.bar([x + 0.2 for x in xs],
        ydata2, width=0.5, color='orange', alpha=0.8, label='ส่งออก')

plt.plot(x, ydata, color='b', marker='s', markersize=8)
plt.plot(x, ydata2, color='r', marker='o', markersize=8)

plt.xlabel("เดือน")
plt.ylabel("ยอดขาย")
plt.title("รานงาน Sales Report")

for tx,ty in list(zip(x, ydata)):
    plt.annotate(ty,
                 (tx, ty),
                 textcoords='offset points',
                 xytext=(0,8),
                 ha='center',
                 fontsize=12)

plt.legend()
plt.ylim(0, 4.5)
plt.show()

# %% [markdown]
# # Workshop 11: Plot graph with Pandas

# %%
import pandas as pd

uri = './score_ageb.xlsx'
df = pd.read_excel(uri)
df.head()
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %% [markdown]
# ## Bar chart

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

df.plot.bar()
plt.suptitle("Age score")
plt.savefig("report01.png")
plt.show()

# %%
cols = ['Age', 'Score']
df[cols].plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## Line graph

# %%
df.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# ## Solid line graph

# %%
df.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# ## Scatter

# %%
df.plot.scatter('Age', 'Score')
# Out:
# <Axes: xlabel='Age', ylabel='Score'>

# %% [markdown]
# ## Boxplot

# %%
cols = ["Age", "Score"]
df[cols].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram

# %%
df['Age'].hist(bins=15)

#df.Score.hist()

#df.Section.hist()
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Score'}>],
#        [<Axes: title={'center': 'Section'}>, <Axes: >]], dtype=object)

# %%
df[['Age', 'Score']].hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Score'}>]], dtype=object)

# %%
df.hist("Score", by='Section', bins=15)
plt.show()

# %% [markdown]
# # Workshop 12: Data Visualization with Seaborn

# %% [markdown]
# ## โหลดข้อมูล

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = sns.load_dataset("tips")

# %% [markdown]
# ## ตรวจสอบข้อมูลเบื้องต้น

# %%
df.head()
#.tail
#.sample(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## ตรวจดูชนิดข้อมูล

# %%
print(df.dtypes)
print(df.info)
print(df.shape)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>
# (244, 7)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['size'] = df['size'].astype('category')
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size          category
# dtype: object

# %%
df.describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %% [markdown]
# ## ตรวจสอบข้อมูลสูญหาย

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# ## ความถี่ของโต๊ะ

# %%
df['size'].hist()
# Out:
# <Axes: >

# %%
sns.countplot(df['size'])
# Out:
# <Axes: xlabel='count', ylabel='size'>

# %%
sns.countplot(x='size', data=df)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
sns.distplot(df['size'], kde=False)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\801843906.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['size'], kde=False)
# <Axes: xlabel='size'>

# %%
sns.countplot(df['size'])
plt.savefig('chart1.png')

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
df['size'].value_counts().to_frame(name='freq')
# Out:
#       freq
# size
# 2      156
# 3       38
# 4       37
# 5        5
# 1        4
# 6        4

# %%
pd.DataFrame(df['size'].value_counts())
# Out:
#       count
# size
# 2       156
# 3        38
# 4        37
# 5         5
# 1         4
# 6         4

# %%
pvt = df.pivot_table(index='size', values='total_bill', aggfunc='count')
pvt
# Out:
#       total_bill
# size
# 1              4
# 2            156
# 3             38
# 4             37
# 5              5
# 6              4

# %%
pvt.sort_values(by='total_bill', ascending=False)
# Out:
#       total_bill
# size
# 2            156
# 3             38
# 4             37
# 5              5
# 1              4
# 6              4

# %% [markdown]
# # ตกแต่งกราฟ

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
plt.rcParams.update({'font.size':16, 'font.family':'tahoma'})
plt.title("ลูกค้า - Day : Sorting")
sns.countplot(x="day", data=df, order=['Sat', 'Sun', 'Thur', 'Fri'])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['day'].value_counts().to_frame(name='freq').sort_values('freq', ascending=False)
# Out:
#       freq
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19

# %% [markdown]
# ## ยอดค่าอาหารเฉลี่ย วันไหนมากสุด

# %%
plt.title("ค่าอาหาร Bill - Day")
sns.barplot(x="day", y="total_bill", data=df)
plt.show()

# %%
plt.title("ค่าอาหาร Bill - Day")
sns.lineplot(x="day", y='total_bill', data=df)
# Out:
# <Axes: title={'center': 'ค่าอาหาร Bill - Day'}, xlabel='day', ylabel='total_bill'>

# %%
sns.lineplot(x="day", y='total_bill', data=df, ci=None)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\3221374370.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="day", y='total_bill', data=df, ci=None)
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## barplot

# %%
pvt = df.pivot_table(index='day', values='total_bill',
                     aggfunc=['mean','min','max','std',])
pvt
# Out:
#            mean        min        max        std
#      total_bill total_bill total_bill total_bill
# day
# Thur  17.682742       7.51      43.11   7.886170
# Fri   17.151579       5.75      40.17   8.302660
# Sat   20.441379       3.07      50.81   9.480419
# Sun   21.410000       7.25      48.17   8.832122

# %%
df.groupby("day").total_bill.mean().sort_index(ascending=False)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2721076068.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("day").total_bill.mean().sort_index(ascending=False)
# day
# Sun     21.410000
# Sat     20.441379
# Fri     17.151579
# Thur    17.682742
# Name: total_bill, dtype: float64

# %%
df.groupby("day").total_bill.min().sort_index(ascending=False)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\1158863281.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("day").total_bill.min().sort_index(ascending=False)
# day
# Sun     7.25
# Sat     3.07
# Fri     5.75
# Thur    7.51
# Name: total_bill, dtype: float64

# %%
df.groupby("day").total_bill.sum().sort_index(ascending=False)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2640822158.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("day").total_bill.sum().sort_index(ascending=False)
# day
# Sun     1627.16
# Sat     1778.40
# Fri      325.88
# Thur    1096.33
# Name: total_bill, dtype: float64

# %%
df.groupby("day").total_bill.sum().sort_index(ascending=False).reset_index()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2140870354.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("day").total_bill.sum().sort_index(ascending=False).reset_index()
#     day  total_bill
# 0   Sun     1627.16
# 1   Sat     1778.40
# 2   Fri      325.88
# 3  Thur     1096.33

# %%
group_data = df.groupby("day").sum(numeric_only=True).reset_index()
group_data = df.groupby(['day','sex']).sum(numeric_only=True).reset_index()
group_data = df.groupby('day').sum(numeric_only=True).sort_values("total_bill").reset_index()
group_data
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\1254718619.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_data = df.groupby("day").sum(numeric_only=True).reset_index()
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\1254718619.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_data = df.groupby(['day','sex']).sum(numeric_only=True).reset_index()
# ...

# %%
group_data.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## กราฟดูยอดรวม

# %%
pvt = df.pivot_table(index='day', values='total_bill', aggfunc=['sum'])

#pvt.columns = pvt.columns.droplevel()
pvt.columns = pvt.columns.get_level_values(1)

pvt.plot.bar()
# Out:
# <Axes: xlabel='day'>

# %%
sns.barplot(x=pvt.index, y='total_bill', data=pvt)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
group_data = df.groupby('day').sum(numeric_only=True).reset_index()

sns.barplot(x='day', y='total_bill', data=group_data, palette='Set2')
sns.lineplot(x='day', y='total_bill', data=group_data, markers='s', color='r')

for index, row in group_data.iterrows():
    plt.annotate(round(row.total_bill, 2),
                 (row.name, row.total_bill),
                 textcoords='offset points',
                 xytext=(0, 2),
                 ha='center',
                 fontsize=15)

plt.title("ยอดขายรวม (Total Bill) By Day")
plt.show()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2187586013.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_data = df.groupby('day').sum(numeric_only=True).reset_index()
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2187586013.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day', y='total_bill', data=group_data, palette='Set2')

# %% [markdown]
# ## mean min max std

# %%
pvt = df.pivot_table(index="sex", values='total_bill',
                     aggfunc=['mean','min','max','sum','std'])

pvt
# Out:
#              mean        min        max        sum        std
#        total_bill total_bill total_bill total_bill total_bill
# sex
# Male    20.744076       7.25      50.81    3256.82   9.246469
# Female  18.056897       3.07      44.30    1570.95   8.009209

# %% [markdown]
# ## graph sum and mean of total_bill

# %%
pvt = df.pivot_table(index="sex", values='total_bill', aggfunc=['sum'])
pvt.columns = pvt.columns.get_level_values(1)

pvt.plot.bar()
plt.title("ค่าอาหารรวม")
# Out:
# Text(0.5, 1.0, 'ค่าอาหารรวม')

# %%
sns.barplot(x='sex', y='total_bill', data=df)
plt.show()

# %% [markdown]
# ## amount of customer by gender

# %%
df.groupby('sex').total_bill.count()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\1114098146.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex').total_bill.count()
# sex
# Male      157
# Female     87
# Name: total_bill, dtype: int64

# %%
sns.countplot(x='sex', data=df)
plt.show()

# %% [markdown]
# ## จัดโต๊ะแบ่งโซน

# %%
pvt = df.pivot_table(index='smoker', values='total_bill', aggfunc=['sum']).reset_index()
pvt.plot.bar()
# Out:
# <Axes: >

# %%
smk = df.groupby(['smoker']).total_bill.sum().reset_index()
sns.barplot(x='smoker', y='total_bill', data=smk)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\4286889618.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   smk = df.groupby(['smoker']).total_bill.sum().reset_index()
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
pvt = df.pivot_table(index='day', columns='smoker', values='total_bill', aggfunc=['count'])
pvt
# Out:
#        count
# smoker   Yes  No
# day
# Thur      17  45
# Fri       15   4
# Sat       42  45
# Sun       19  57

# %%
sns.countplot(x=df.day, hue=df.smoker)
plt.legend(loc='lower right')
plt.title("สรุป zone - day")
# Out:
# Text(0.5, 1.0, 'สรุป zone - day')

# %% [markdown]
# ## distplot

# %%
sns.distplot(df.total_bill, bins=20, color='g')
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2512963721.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.total_bill, bins=20, color='g')
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
df.total_bill.hist(bins=20)
df.hist('total_bill', bins=20)
# Out:
# array([[<Axes: title={'center': 'total_bill'}>]], dtype=object)

# %% [markdown]
# ## kdeplot

# %%
sns.kdeplot(df.total_bill, shade=True)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2351788894.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.total_bill, shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x='total_bill', data=df)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(df.total_bill)
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y='total_bill', data=df)
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y='total_bill', data=df, width=0.3)
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# # Workshop 13: การเปรียบเทียบข้อมูล

# %% [markdown]
# ## plot histogram with pandas

# %%
df.hist('total_bill', bins=10, by='time')
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\980455582.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.hist('total_bill', bins=10, by='time')
# array([<Axes: title={'center': 'Lunch'}>,
#        <Axes: title={'center': 'Dinner'}>], dtype=object)

# %%
df.groupby('time').total_bill.mean().to_frame()\
    .sort_values('total_bill', ascending=False)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\3020649931.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('time').total_bill.mean().to_frame()\
#         total_bill
# time
# Dinner   20.797159
# Lunch    17.168676

# %%
pvt = df.pivot_table(index='time', values='total_bill') 
pvt
# Out:
#         total_bill
# time
# Lunch    17.168676
# Dinner   20.797159

# %% [markdown]
# ## Compare with FacedGrid

# %%
sns.set_style('darkgrid')
grid = sns.FacetGrid(df, row='smoker', col='time')
grid.map(plt.hist, 'total_bill', bins=10)

# %% [markdown]
# ## Compare with Boxplt

# %%
sns.boxplot(x=df.time, y=df.total_bill, width=0.4)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(x='time', y='total_bill', data=df, width=0.4, palette='husl')
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\2338961041.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='time', y='total_bill', data=df, width=0.4, palette='husl')
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(x=df.time, y=df.total_bill, order=['Dinner','Lunch'])
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(x=df.time, y=df.total_bill, hue=df.smoker, width=0.4, palette='husl', order=['Lunch','Dinner'])
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ## ข้อมูลสรุป Q1 Q2 Q3 สำหรับ Boxplot

# %%
df.groupby(['time']).total_bill.quantile([.25,.5,.75]).to_frame()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\3965884475.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['time']).total_bill.quantile([.25,.5,.75]).to_frame()
#              total_bill
# time
# Lunch  0.25     12.2350
#        0.50     15.9650
#        0.75     19.5325
# Dinner 0.25     14.4375
#        0.50     18.3900
#        0.75     25.2825

# %%
df.groupby(['time']).total_bill.quantile([.25,.5,.75]).to_frame().T
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\3490620623.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['time']).total_bill.quantile([.25,.5,.75]).to_frame().T
# time         Lunch                    Dinner
#               0.25    0.50     0.75     0.25   0.50     0.75
# total_bill  12.235  15.965  19.5325  14.4375  18.39  25.2825

# %%
sns.boxplot(x=df.smoker, y=df.total_bill, width=0.5)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x=df['day'], y=df.total_bill, width=0.6, hue=df.smoker)
plt.legend(loc="upper left")

# %% [markdown]
# ## คิดยอดรวม

# %%
pvt = df.pivot_table(index='day', columns='smoker', values='total_bill', aggfunc=['sum', 'count'])
pvt.plot.bar()
pvt
# Out:
#            sum          count
# smoker     Yes       No   Yes  No
# day
# Thur    326.24   770.09    17  45
# Fri     252.20    73.68    15   4
# Sat     893.62   884.78    42  45
# Sun     458.28  1168.88    19  57

# %% [markdown]
# ## กราฟ Violonplot

# %%
sns.violinplot(df.total_bill)
#sns.violinplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.violinplot(x="total_bill", data=df)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(y="total_bill", data=df)
#sns.violinplot(y= df.total_bill)
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.violinplot(x='time', y='total_bill', data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
ord = ['Fri','Thur', 'Sat', 'Sun']
sns.violinplot(x='day', y='total_bill', data=df, order=ord)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=df, hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Violin แบ่ง 2 ซีก

# %%
sns.violinplot(x='day', y='total_bill', data=df, hue='smoker', split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### กราฟ Swarplot

# %%
sns.set_style('whitegrid')
sns.swarmplot(x='sex', y='total_bill', data=df)
#sns.swarmplot(x='sex', y='total_bill', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
pvt = df.pivot_table(index='sex', values='total_bill')
#df.groupby('sex').total_bill.mean().to_frame()
pvt
# Out:
#         total_bill
# sex
# Male     20.744076
# Female   18.056897

# %%
sns.swarmplot(x='day', y='total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#เลือกแบบไหนก็ได้
pvt = df.pivot_table(index='day', values='total_bill')
pvt.sort_values('total_bill', ascending=False) #มากไปน้อย
# Out:
#       total_bill
# day
# Sun    21.410000
# Sat    20.441379
# Thur   17.682742
# Fri    17.151579

# %%
#แบบเรียง
df.groupby('day').total_bill.mean().to_frame().sort_values('total_bill', ascending=False)
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_344\537374383.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day').total_bill.mean().to_frame().sort_values('total_bill', ascending=False)
#       total_bill
# day
# Sun    21.410000
# Sat    20.441379
# Thur   17.682742
# Fri    17.151579
